# %%
import pandas as pd
import numpy as np
from ExperimentSetting import *

# %%
branch_probability_thresholds=[np.inf]
filter_approaches=['probability']
df_names=['breast cancer','iris','winery']
#df_names=['iris']
#number_of_estimators_list=[200,100,50,10]
number_of_estimators_list=[2,3]
fixed_params={}
num_of_iterations=10
experimentSetting1=ExperimentSetting(branch_probability_thresholds,df_names,
                                     number_of_estimators_list,fixed_params,num_of_iterations,filter_approaches)

# %%
experimentSetting1.run()
# Out:
# {'number_of_estimators': 2, 'max_number_of_branches': inf, 'df_name': 'breast cancer', 'filter_approach': 'probability'}
# 0
# number of branches before filterring: 247
# number of branches after filterring: 247
# i=0
# 1
# number of branches before filterring: 207
# number of branches after filterring: 207
# i=0
# 2
# number of branches before filterring: 351
# number of branches after filterring: 351
# i=0
# 3
# number of branches before filterring: 179
# number of branches after filterring: 179
# i=0
# 4
# number of branches before filterring: 181
# number of branches after filterring: 181
# i=0
# 5
# number of branches before filterring: 232
# number of branches after filterring: 232
# i=0
# 6
# number of branches before filterring: 193
# number of branches after filterring: 193
# i=0
# 7
# number of branches before filterring: 403
# number of branches after filterring: 403
# i=0
# 8
# number of branches before filterring: 255
# number of branches after filterring: 255
# i=0
# 9
# number of branches before filterring: 284
# number of branches after filterring: 284
# i=0
# {'number_of_estimators': 3, 'max_number_of_branches': inf, 'df_name': 'breast cancer', 'filter_approach': 'probability'}
# 0
# number of branches before filterring: 250
# number of branches after filterring: 250
# i=0
# number of branches before filterring: 1588
# number of branches after filterring: 1588
# i=1
# 1
# number of branches before filterring: 276
# number of branches after filterring: 276
# i=0
# number of branches before filterring: 2074
# number of branches after filterring: 2074
# i=1
# 2
# number of branches before filterring: 202
# number of branches after filterring: 202
# i=0
# number of branches before filterring: 1246
# number of branches after filterring: 1246
# i=1
# 3
# number of branches before filterring: 249
# number of branches after filterring: 249
# i=0
# number of branches before filterring: 1752
# number of branches after filterring: 1752
# i=1
# 4
# number of branches before filterring: 171
# number of branches after filterring: 171
# i=0
# number of branches before filterring: 891
# number of branches after filterring: 891
# i=1
# 5
# number of branches before filterring: 387
# number of branches after filterring: 387
# i=0
# number of branches before filterring: 3100
# number of branches after filterring: 3100
# i=1
# 6
# number of branches before filterring: 180
# number of branches after filterring: 180
# i=0
# number of branches before filterring: 1368
# number of branches after filterring: 1368
# i=1
# 7
# number of branches before filterring: 144
# number of branches after filterring: 144
# i=0
# number of branches before filterring: 1304
# number of branches after filterring: 1304
# i=1
# 8
# number of branches before filterring: 215
# number of branches after filterring: 215
# i=0
# number of branches before filterring: 1559
# number of branches after filterring: 1559
# i=1
# 9
# number of branches before filterring: 241
# number of branches after filterring: 241
# i=0
# number of branches before filterring: 1327
# number of branches after filterring: 1327
# i=1
# {'number_of_estimators': 2, 'max_number_of_branches': inf, 'df_name': 'iris', 'filter_approach': 'probability'}
# 0
# number of branches before filterring: 24
# number of branches after filterring: 24
# i=0
# 1
# number of branches before filterring: 12
# number of branches after filterring: 12
# i=0
# 2
# number of branches before filterring: 18
# number of branches after filterring: 18
# i=0
# 3
# number of branches before filterring: 22
# number of branches after filterring: 22
# i=0
# 4
# number of branches before filterring: 29
# number of branches after filterring: 29
# i=0
# 5
# number of branches before filterring: 43
# number of branches after filterring: 43
# i=0
# 6
# number of branches before filterring: 10
# number of branches after filterring: 10
# i=0
# 7
# number of branches before filterring: 25
# number of branches after filterring: 25
# i=0
# 8
# number of branches before filterring: 13
# number of branches after filterring: 13
# i=0
# 9
# number of branches before filterring: 28
# number of branches after filterring: 28
# i=0
# {'number_of_estimators': 3, 'max_number_of_branches': inf, 'df_name': 'iris', 'filter_approach': 'probability'}
# 0
# number of branches before filterring: 15
# number of branches after filterring: 15
# i=0
# number of branches before filterring: 24
# number of branches after filterring: 24
# i=1
# 1
# number of branches before filterring: 31
# number of branches after filterring: 31
# i=0
# number of branches before filterring: 109
# number of branches after filterring: 109
# i=1
# 2
# number of branches before filterring: 15
# number of branches after filterring: 15
# i=0
# number of branches before filterring: 51
# number of branches after filterring: 51
# i=1
# 3
# number of branches before filterring: 36
# number of branches after filterring: 36
# i=0
# number of branches before filterring: 90
# number of branches after filterring: 90
# i=1
# 4
# number of branches before filterring: 17
# number of branches after filterring: 17
# i=0
# number of branches before filterring: 57
# number of branches after filterring: 57
# i=1
# 5
# number of branches before filterring: 28
# number of branches after filterring: 28
# i=0
# number of branches before filterring: 48
# number of branches after filterring: 48
# i=1
# 6
# number of branches before filterring: 9
# number of branches after filterring: 9
# i=0
# number of branches before filterring: 34
# number of branches after filterring: 34
# i=1
# 7
# number of branches before filterring: 11
# number of branches after filterring: 11
# i=0
# number of branches before filterring: 31
# number of branches after filterring: 31
# i=1
# 8
# number of branches before filterring: 19
# number of branches after filterring: 19
# i=0
# number of branches before filterring: 50
# number of branches after filterring: 50
# i=1
# 9
# number of branches before filterring: 44
# number of branches after filterring: 44
# i=0
# number of branches before filterring: 61
# number of branches after filterring: 61
# i=1
# {'number_of_estimators': 2, 'max_number_of_branches': inf, 'df_name': 'winery', 'filter_approach': 'probability'}
# 0
# number of branches before filterring: 77
# number of branches after filterring: 77
# i=0
# 1
# number of branches before filterring: 92
# number of branches after filterring: 92
# i=0
# 2
# number of branches before filterring: 36
# number of branches after filterring: 36
# i=0
# 3
# number of branches before filterring: 135
# number of branches after filterring: 135
# i=0
# 4
# number of branches before filterring: 133
# number of branches after filterring: 133
# i=0
# 5
# number of branches before filterring: 50
# number of branches after filterring: 50
# i=0
# 6
# number of branches before filterring: 63
# number of branches after filterring: 63
# i=0
# 7
# number of branches before filterring: 71
# number of branches after filterring: 71
# i=0
# 8
# number of branches before filterring: 107
# number of branches after filterring: 107
# i=0
# 9
# number of branches before filterring: 77
# number of branches after filterring: 77
# i=0
# {'number_of_estimators': 3, 'max_number_of_branches': inf, 'df_name': 'winery', 'filter_approach': 'probability'}
# 0
# number of branches before filterring: 44
# number of branches after filterring: 44
# i=0
# number of branches before filterring: 289
# number of branches after filterring: 289
# i=1
# 1
# number of branches before filterring: 111
# number of branches after filterring: 111
# i=0
# number of branches before filterring: 452
# number of branches after filterring: 452
# i=1
# 2
# number of branches before filterring: 68
# number of branches after filterring: 68
# i=0
# number of branches before filterring: 357
# number of branches after filterring: 357
# i=1
# 3
# number of branches before filterring: 92
# number of branches after filterring: 92
# i=0
# number of branches before filterring: 774
# number of branches after filterring: 774
# i=1
# 4
# number of branches before filterring: 88
# number of branches after filterring: 88
# i=0
# number of branches before filterring: 367
# number of branches after filterring: 367
# i=1
# 5
# number of branches before filterring: 112
# number of branches after filterring: 112
# i=0
# number of branches before filterring: 511
# number of branches after filterring: 511
# i=1
# 6
# number of branches before filterring: 34
# number of branches after filterring: 34
# i=0
# number of branches before filterring: 199
# number of branches after filterring: 199
# i=1
# 7
# number of branches before filterring: 58
# number of branches after filterring: 58
# i=0
# number of branches before filterring: 217
# number of branches after filterring: 217
# i=1
# 8
# number of branches before filterring: 63
# number of branches after filterring: 63
# i=0
# number of branches before filterring: 229
# number of branches after filterring: 229
# i=1
# 9
# number of branches before filterring: 78
# number of branches after filterring: 78
# i=0
# number of branches before filterring: 425
# number of branches after filterring: 425
# i=1

# %%
df.columns
# Out:
# Index(['conjunction set training time', 'decision tree training time',
#        'decision_tree_accuracy', 'decision_tree_auc',
#        'decision_tree_average_depth', 'decision_tree_max_depth',
#        'decision_tree_min_depth', 'df_name', 'ensemble max_depth',
#        'ensemble_accuracy', 'ensemble_auc', 'ensemble_average_depth',
#        'ensemble_min_depth', 'filter_approach', 'iteration',
#        'max_number_of_branches', 'new model training time',
#        'new_model_accuracy', 'new_model_auc', 'new_model_average_depth',
#        'new_model_max_depth', 'new_model_min_depth',
#        'number of branches per iteration', 'number_of_branches',
#        'number_of_estimators', 'random forest training time',
#        'sklearn_vs_our_ensemble_predictions_disagreements'],
#       dtype='object')

# %%
df=pd.DataFrame(experimentSetting1.experiments)
groups=['df_name','number_of_estimators','filter_approach']
df[[col for col in df.columns if 'accuracy' in col]+groups].groupby(groups).mean()
# Out:
#                                                     decision_tree_accuracy  \
# df_name       number_of_estimators filter_approach
# breast cancer 2                    probability                    0.959512
#               3                    probability                    0.952195
# iris          2                    probability                    0.957778
#               3                    probability                    0.937778
# winery        2                    probability                    0.922222
#               3                    probability                    0.927778
#
#                                                     ensemble_accuracy  \
# df_name       number_of_estimators filter_approach
# breast cancer 2                    probability               0.940976
#               3                    probability               0.955610
# iris          2                    probability               0.942222
#               3                    probability               0.940000
# winery        2                    probability               0.872222
#               3                    probability               0.931481
#
#                                                     new_model_accuracy
# df_name       number_of_estimators filter_approach
# breast cancer 2                    probability                0.940976
#               3                    probability                0.955610
# iris          2                    probability                0.942222
#               3                    probability                0.940000
# winery        2                    probability                0.872222
#               3                    probability                0.929630

# %%
df=pd.DataFrame(experimentSetting1.experiments)
df[[col for col in df.columns if 'auc' in col]+groups].groupby(groups).mean()
# Out:
#                                                     decision_tree_auc  \
# df_name       number_of_estimators filter_approach
# breast cancer 2                    probability               0.973739
#               3                    probability               0.963156
# iris          2                    probability               0.971988
#               3                    probability               0.966815
# winery        2                    probability               0.948422
#               3                    probability               0.948903
#
#                                                     ensemble_auc  \
# df_name       number_of_estimators filter_approach
# breast cancer 2                    probability          0.978532
#               3                    probability          0.973466
# iris          2                    probability          0.977988
#               3                    probability          0.971309
# winery        2                    probability          0.959688
#               3                    probability          0.984714
#
#                                                     new_model_auc
# df_name       number_of_estimators filter_approach
# breast cancer 2                    probability           0.978421
#               3                    probability           0.973118
# iris          2                    probability           0.977988
#               3                    probability           0.971358
# winery        2                    probability           0.959688
#               3                    probability           0.984465

# %%
df=pd.DataFrame(experimentSetting1.experiments)
df[[col for col in df.columns if 'time' in col]+groups].groupby(groups).mean()

# %%
df=pd.DataFrame(experimentSetting1.experiments)
df[[col for col in df.columns if 'average_depth' in col]+groups].groupby(groups).mean()

# %%
df.to_csv('experimetn_29_4_18.csv')
